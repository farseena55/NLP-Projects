# %% [markdown]
# <!-- what is NLP?
# NLP is a branch of AI that enables computers to comprehend, generate and manipulate human language
#
# Preprocessing steps for NLP
#
# 1.Text cleaning
#  --> * converting into lower cases
#      * removing URLS
#      *removing remove non-word and non-white space characters
#      * removing digits
#
# 2. Tokenization
#
# 3. stopword removal
#
# 4. stemming/lemmatization
#
# stemming algorithms
#
# 1.porter stemmer algorithm
# 2. snowball stemmer
# lovins stemmer
#
# types of tokenization
#
# 1.word tokenization
# 2.character tokenization
# subword tokenization
#
# vectorisation
#
# techniques
# 1. TFIDF
# 2.word2vec

# %% [markdown]
# TF - Token frequency
# IDF - inverse document frequency
# TD - total documents
# AD - Available document
